# %% [markdown]
# Create a Python script named matplotlib_test_results.py that:
# 1. Stores the number of test cases executed in a release: o Passed = 45
# o Failed = 10
# o Skipped = 5
# 2. Use Matplotlib to plot a bar chart showing these results.
# 3. Add chart title: "Test Execution Results"
# 4. Add axis labels:
# o X-axis → "Test Status"
# o Y-axis → "Number of Test Cases" 5. Display the chart..

# %%
import matplotlib.pyplot as plt

# %%
test_results = {
    "Passed": 45,
    "Failed": 10,
    "Skipped": 5
}

# %%
test_statuses = list(test_results.keys())
number_of_cases = list(test_results.values())

# %%
plt.bar(test_statuses, number_of_cases, width=0.3, edgecolor = 'k', color=['green', 'red', 'orange'])
plt.xlabel("Test Status")
plt.ylabel("Number of Cases")
plt.title("Test Execution Results")
plt.show()
